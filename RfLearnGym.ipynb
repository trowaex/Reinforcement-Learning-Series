# %%
import tensorflow as tf
import gym
import numpy as np

### Variables
num_inputs = 4
num_hidden = 4
num_outputs = 1

learning_rate = 0.01

initializer = tf.contrib.layers.variance_scaling_initializer()


### Create networks
X = tf.placeholder(tf.float32, shape=[None, num_inputs])

hidden_layer = tf.layers.dense(X, num_hidden, activation=tf.nn.elu, kernel_initializer=initializer)
logits = tf.layers.dense(hidden_layer, num_outputs)
outputs = tf.nn.sigmoid(logits)  # probability of action 0 (left)

probabilties = tf.concat(axis=1, values=[outputs, 1 - outputs])
action = tf.multinomial( probabilties, num_samples=1)

y = 1. - tf.to_float(action)


### Lost func and Optimizer
cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
optimizer = tf.train.AdamOptimizer(learning_rate)



### Gradient
gradients_and_variables = optimizer.compute_gradients(cross_entropy)



gradients = []
gradient_placeholders = []
grads_and_vars_feed = []

for gradient, variable in gradients_and_variables:
    gradients.append(gradient)
    gradient_placeholder = tf.placeholder(tf.float32, shape=gradient.get_shape())
    gradient_placeholders.append(gradient_placeholder)
    grads_and_vars_feed.append((gradient_placeholder, variable))


training_op = optimizer.apply_gradients(grads_and_vars_feed)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
### Reward functions ###

def helper_discount_rewards(rewards, discount_rate):
    '''
    Takes in rewards and applies discount rate
    '''
    discounted_rewards = np.zeros(len(rewards))
    cumulative_rewards = 0
    for step in reversed(range(len(rewards))):
        cumulative_rewards = rewards[step] + cumulative_rewards * discount_rate
        discounted_rewards[step] = cumulative_rewards
    return discounted_rewards

def discount_and_normalize_rewards(all_rewards, discount_rate):
    '''
    Takes in all rewards, applies helper_discount function and then normalizes
    using mean and std.
    '''
    all_discounted_rewards = []
    for rewards in all_rewards:
        all_discounted_rewards.append(helper_discount_rewards(rewards,discount_rate))

    flat_rewards = np.concatenate(all_discounted_rewards)
    reward_mean = flat_rewards.mean()
    reward_std = flat_rewards.std()
    return [(discounted_rewards - reward_mean)/reward_std for discounted_rewards in all_discounted_rewards]

# %%
### Training
env = gym.make("CartPole-v0")

num_game_rounds = 10
max_game_steps = 1000
num_iterations = 650
discount_rate = 0.95

with tf.Session() as sess:
    sess.run(init)


    for iteration in range(num_iterations):
        print("Currently on Iteration: {} \n".format(iteration) )

        all_rewards = []
        all_gradients = []

        # Play n amount of game rounds
        for game in range(num_game_rounds):

            current_rewards = []
            current_gradients = []

            observations = env.reset()

            # Only allow n amount of steps in game
            for step in range(max_game_steps):

                # Get Actions and Gradients
                action_val, gradients_val = sess.run([action, gradients], feed_dict={X: observations.reshape(1, num_inputs)})

                # Perform Action
                observations, reward, done, info = env.step(action_val[0][0])

                # Get Current Rewards and Gradients
                current_rewards.append(reward)
                current_gradients.append(gradients_val)

                if done:
                    # Game Ended
                    break

            # Append to list of all rewards
            all_rewards.append(current_rewards)
            all_gradients.append(current_gradients)

        all_rewards = discount_and_normalize_rewards(all_rewards,discount_rate)
        feed_dict = {}


        for var_index, gradient_placeholder in enumerate(gradient_placeholders):
            mean_gradients = np.mean([reward * all_gradients[game_index][step][var_index]
                                      for game_index, rewards in enumerate(all_rewards)
                                          for step, reward in enumerate(rewards)], axis=0)
            feed_dict[gradient_placeholder] = mean_gradients

        sess.run(training_op, feed_dict=feed_dict)

    print('SAVING GRAPH AND SESSION')
    meta_graph_def = tf.train.export_meta_graph(filename='./models/rf-650-steps-model.meta')
    saver.save(sess, './models/rf-650-steps-model')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Currently on Iteration: 0
#
# Currently on Iteration: 1
#
# Currently on Iteration: 2
#
# Currently on Iteration: 3
#
# Currently on Iteration: 4
#
# Currently on Iteration: 5
#
# Currently on Iteration: 6
#
# Currently on Iteration: 7
#
# Currently on Iteration: 8
#
# Currently on Iteration: 9
#
# Currently on Iteration: 10
#
# Currently on Iteration: 11
#
# Currently on Iteration: 12
#
# Currently on Iteration: 13
#
# Currently on Iteration: 14
#
# Currently on Iteration: 15
#
# Currently on Iteration: 16
#
# Currently on Iteration: 17
#
# Currently on Iteration: 18
#
# Currently on Iteration: 19
#
# Currently on Iteration: 20
#
# Currently on Iteration: 21
#
# Currently on Iteration: 22
#
# Currently on Iteration: 23
#
# Currently on Iteration: 24
#
# Currently on Iteration: 25
#
# Currently on Iteration: 26
#
# Currently on Iteration: 27
#
# Currently on Iteration: 28
#
# Currently on Iteration: 29
#
# Currently on Iteration: 30
#
# Currently on Iteration: 31
#
# Currently on Iteration: 32
#
# Currently on Iteration: 33
#
# Currently on Iteration: 34
#
# Currently on Iteration: 35
#
# Currently on Iteration: 36
#
# Currently on Iteration: 37
#
# Currently on Iteration: 38
#
# Currently on Iteration: 39
#
# Currently on Iteration: 40
#
# Currently on Iteration: 41
#
# Currently on Iteration: 42
#
# Currently on Iteration: 43
#
# Currently on Iteration: 44
#
# Currently on Iteration: 45
#
# Currently on Iteration: 46
#
# Currently on Iteration: 47
#
# Currently on Iteration: 48
#
# Currently on Iteration: 49
#
# Currently on Iteration: 50
#
# Currently on Iteration: 51
#
# Currently on Iteration: 52
#
# Currently on Iteration: 53
#
# Currently on Iteration: 54
#
# Currently on Iteration: 55
#
# Currently on Iteration: 56
#
# Currently on Iteration: 57
#
# Currently on Iteration: 58
#
# Currently on Iteration: 59
#
# Currently on Iteration: 60
#
# Currently on Iteration: 61
#
# Currently on Iteration: 62
#
# Currently on Iteration: 63
#
# Currently on Iteration: 64
#
# Currently on Iteration: 65
#
# Currently on Iteration: 66
#
# Currently on Iteration: 67
#
# Currently on Iteration: 68
#
# Currently on Iteration: 69
#
# Currently on Iteration: 70
#
# Currently on Iteration: 71
#
# Currently on Iteration: 72
#
# Currently on Iteration: 73
#
# Currently on Iteration: 74
#
# Currently on Iteration: 75
#
# Currently on Iteration: 76
#
# Currently on Iteration: 77
#
# Currently on Iteration: 78
#
# Currently on Iteration: 79
#
# Currently on Iteration: 80
#
# Currently on Iteration: 81
#
# Currently on Iteration: 82
#
# Currently on Iteration: 83
#
# Currently on Iteration: 84
#
# Currently on Iteration: 85
#
# Currently on Iteration: 86
#
# Currently on Iteration: 87
#
# Currently on Iteration: 88
#
# Currently on Iteration: 89
#
# Currently on Iteration: 90
#
# Currently on Iteration: 91
#
# Currently on Iteration: 92
#
# Currently on Iteration: 93
#
# Currently on Iteration: 94
#
# Currently on Iteration: 95
#
# Currently on Iteration: 96
#
# Currently on Iteration: 97
#
# Currently on Iteration: 98
#
# Currently on Iteration: 99
#
# Currently on Iteration: 100
#
# Currently on Iteration: 101
#
# Currently on Iteration: 102
#
# Currently on Iteration: 103
#
# Currently on Iteration: 104
#
# Currently on Iteration: 105
#
# Currently on Iteration: 106
#
# Currently on Iteration: 107
#
# Currently on Iteration: 108
#
# Currently on Iteration: 109
#
# Currently on Iteration: 110
#
# Currently on Iteration: 111
#
# Currently on Iteration: 112
#
# Currently on Iteration: 113
#
# Currently on Iteration: 114
#
# Currently on Iteration: 115
#
# Currently on Iteration: 116
#
# Currently on Iteration: 117
#
# Currently on Iteration: 118
#
# Currently on Iteration: 119
#
# Currently on Iteration: 120
#
# Currently on Iteration: 121
#
# Currently on Iteration: 122
#
# Currently on Iteration: 123
#
# Currently on Iteration: 124
#
# Currently on Iteration: 125
#
# Currently on Iteration: 126
#
# Currently on Iteration: 127
#
# Currently on Iteration: 128
#
# Currently on Iteration: 129
#
# Currently on Iteration: 130
#
# Currently on Iteration: 131
#
# Currently on Iteration: 132
#
# Currently on Iteration: 133
#
# Currently on Iteration: 134
#
# Currently on Iteration: 135
#
# Currently on Iteration: 136
#
# Currently on Iteration: 137
#
# Currently on Iteration: 138
#
# Currently on Iteration: 139
#
# Currently on Iteration: 140
#
# Currently on Iteration: 141
#
# Currently on Iteration: 142
#
# Currently on Iteration: 143
#
# Currently on Iteration: 144
#
# Currently on Iteration: 145
#
# Currently on Iteration: 146
#
# Currently on Iteration: 147
#
# Currently on Iteration: 148
#
# Currently on Iteration: 149
#
# Currently on Iteration: 150
#
# Currently on Iteration: 151
#
# Currently on Iteration: 152
#
# Currently on Iteration: 153
#
# Currently on Iteration: 154
#
# Currently on Iteration: 155
#
# Currently on Iteration: 156
#
# Currently on Iteration: 157
#
# Currently on Iteration: 158
#
# Currently on Iteration: 159
#
# Currently on Iteration: 160
#
# Currently on Iteration: 161
#
# Currently on Iteration: 162
#
# Currently on Iteration: 163
#
# Currently on Iteration: 164
#
# Currently on Iteration: 165
#
# Currently on Iteration: 166
#
# Currently on Iteration: 167
#
# Currently on Iteration: 168
#
# Currently on Iteration: 169
#
# Currently on Iteration: 170
#
# Currently on Iteration: 171
#
# Currently on Iteration: 172
#
# Currently on Iteration: 173
#
# Currently on Iteration: 174
#
# Currently on Iteration: 175
#
# Currently on Iteration: 176
#
# Currently on Iteration: 177
#
# Currently on Iteration: 178
#
# Currently on Iteration: 179
#
# Currently on Iteration: 180
#
# Currently on Iteration: 181
#
# Currently on Iteration: 182
#
# Currently on Iteration: 183
#
# Currently on Iteration: 184
#
# Currently on Iteration: 185
#
# Currently on Iteration: 186
#
# Currently on Iteration: 187
#
# Currently on Iteration: 188
#
# Currently on Iteration: 189
#
# Currently on Iteration: 190
#
# Currently on Iteration: 191
#
# Currently on Iteration: 192
#
# Currently on Iteration: 193
#
# Currently on Iteration: 194
#
# Currently on Iteration: 195
#
# Currently on Iteration: 196
#
# Currently on Iteration: 197
#
# Currently on Iteration: 198
#
# Currently on Iteration: 199
#
# Currently on Iteration: 200
#
# Currently on Iteration: 201
#
# Currently on Iteration: 202
#
# Currently on Iteration: 203
#
# Currently on Iteration: 204
#
# Currently on Iteration: 205
#
# Currently on Iteration: 206
#
# Currently on Iteration: 207
#
# Currently on Iteration: 208
#
# Currently on Iteration: 209
#
# Currently on Iteration: 210
#
# Currently on Iteration: 211
#
# Currently on Iteration: 212
#
# Currently on Iteration: 213
#
# Currently on Iteration: 214
#
# Currently on Iteration: 215
#
# Currently on Iteration: 216
#
# Currently on Iteration: 217
#
# Currently on Iteration: 218
#
# Currently on Iteration: 219
#
# Currently on Iteration: 220
#
# Currently on Iteration: 221
#
# Currently on Iteration: 222
#
# Currently on Iteration: 223
#
# Currently on Iteration: 224
#
# Currently on Iteration: 225
#
# Currently on Iteration: 226
#
# Currently on Iteration: 227
#
# Currently on Iteration: 228
#
# Currently on Iteration: 229
#
# Currently on Iteration: 230
#
# Currently on Iteration: 231
#
# Currently on Iteration: 232
#
# Currently on Iteration: 233
#
# Currently on Iteration: 234
#
# Currently on Iteration: 235
#
# Currently on Iteration: 236
#
# Currently on Iteration: 237
#
# Currently on Iteration: 238
#
# Currently on Iteration: 239
#
# Currently on Iteration: 240
#
# Currently on Iteration: 241
#
# Currently on Iteration: 242
#
# Currently on Iteration: 243
#
# Currently on Iteration: 244
#
# Currently on Iteration: 245
#
# Currently on Iteration: 246
#
# Currently on Iteration: 247
#
# Currently on Iteration: 248
#
# Currently on Iteration: 249
#
# Currently on Iteration: 250
#
# Currently on Iteration: 251
#
# Currently on Iteration: 252
#
# Currently on Iteration: 253
#
# Currently on Iteration: 254
#
# Currently on Iteration: 255
#
# Currently on Iteration: 256
#
# Currently on Iteration: 257
#
# Currently on Iteration: 258
#
# Currently on Iteration: 259
#
# Currently on Iteration: 260
#
# Currently on Iteration: 261
#
# Currently on Iteration: 262
#
# Currently on Iteration: 263
#
# Currently on Iteration: 264
#
# Currently on Iteration: 265
#
# Currently on Iteration: 266
#
# Currently on Iteration: 267
#
# Currently on Iteration: 268
#
# Currently on Iteration: 269
#
# Currently on Iteration: 270
#
# Currently on Iteration: 271
#
# Currently on Iteration: 272
#
# Currently on Iteration: 273
# Currently on Iteration: 274
#
# Currently on Iteration: 275
#
# Currently on Iteration: 276
#
# Currently on Iteration: 277
#
# Currently on Iteration: 278
#
# Currently on Iteration: 279
#
# Currently on Iteration: 280
#
# Currently on Iteration: 281
#
# Currently on Iteration: 282
#
# Currently on Iteration: 283
#
# Currently on Iteration: 284
#
# Currently on Iteration: 285
#
# Currently on Iteration: 286
#
# Currently on Iteration: 287
#
# Currently on Iteration: 288
#
# Currently on Iteration: 289
#
# Currently on Iteration: 290
#
# Currently on Iteration: 291
#
# Currently on Iteration: 292
#
# Currently on Iteration: 293
#
# Currently on Iteration: 294
#
# Currently on Iteration: 295
#
# Currently on Iteration: 296
#
# Currently on Iteration: 297
#
# Currently on Iteration: 298
#
# Currently on Iteration: 299
#
# Currently on Iteration: 300
#
# Currently on Iteration: 301
#
# Currently on Iteration: 302
#
# Currently on Iteration: 303
#
# Currently on Iteration: 304
#
# Currently on Iteration: 305
#
# Currently on Iteration: 306
#
# Currently on Iteration: 307
#
# Currently on Iteration: 308
#
# Currently on Iteration: 309
#
# Currently on Iteration: 310
#
# Currently on Iteration: 311
#
# Currently on Iteration: 312
#
# Currently on Iteration: 313
#
# Currently on Iteration: 314
#
# Currently on Iteration: 315
#
# Currently on Iteration: 316
#
# Currently on Iteration: 317
#
# Currently on Iteration: 318
#
# Currently on Iteration: 319
#
# Currently on Iteration: 320
#
# Currently on Iteration: 321
#
# Currently on Iteration: 322
#
# Currently on Iteration: 323
#
# Currently on Iteration: 324
#
# Currently on Iteration: 325
#
# Currently on Iteration: 326
#
# Currently on Iteration: 327
#
# Currently on Iteration: 328
#
# Currently on Iteration: 329
#
# Currently on Iteration: 330
#
# Currently on Iteration: 331
#
# Currently on Iteration: 332
#
# Currently on Iteration: 333
#
# Currently on Iteration: 334
#
# Currently on Iteration: 335
#
# Currently on Iteration: 336
#
# Currently on Iteration: 337
#
# Currently on Iteration: 338
#
# Currently on Iteration: 339
#
# Currently on Iteration: 340
#
# Currently on Iteration: 341
#
# Currently on Iteration: 342
#
# Currently on Iteration: 343
#
# Currently on Iteration: 344
#
# Currently on Iteration: 345
#
# Currently on Iteration: 346
#
# Currently on Iteration: 347
#
# Currently on Iteration: 348
#
# Currently on Iteration: 349
#
# Currently on Iteration: 350
#
# Currently on Iteration: 351
#
# Currently on Iteration: 352
#
# Currently on Iteration: 353
#
# Currently on Iteration: 354
#
# Currently on Iteration: 355
#
# Currently on Iteration: 356
#
# Currently on Iteration: 357
#
# Currently on Iteration: 358
#
# Currently on Iteration: 359
#
# Currently on Iteration: 360
#
# Currently on Iteration: 361
#
# Currently on Iteration: 362
#
# Currently on Iteration: 363
#
# Currently on Iteration: 364
#
# Currently on Iteration: 365
#
# Currently on Iteration: 366
#
# Currently on Iteration: 367
#
# Currently on Iteration: 368
#
# Currently on Iteration: 369
#
# Currently on Iteration: 370
#
# Currently on Iteration: 371
#
# Currently on Iteration: 372
#
# Currently on Iteration: 373
#
# Currently on Iteration: 374
#
# Currently on Iteration: 375
#
# Currently on Iteration: 376
#
# Currently on Iteration: 377
#
# Currently on Iteration: 378
#
# Currently on Iteration: 379
#
# Currently on Iteration: 380
#
# Currently on Iteration: 381
#
# Currently on Iteration: 382
#
# Currently on Iteration: 383
#
# Currently on Iteration: 384
#
# Currently on Iteration: 385
#
# Currently on Iteration: 386
#
# Currently on Iteration: 387
#
# Currently on Iteration: 388
#
# Currently on Iteration: 389
#
# Currently on Iteration: 390
#
# Currently on Iteration: 391
#
# Currently on Iteration: 392
#
# Currently on Iteration: 393
#
# Currently on Iteration: 394
#
# Currently on Iteration: 395
#
# Currently on Iteration: 396
#
# Currently on Iteration: 397
#
# Currently on Iteration: 398
#
# Currently on Iteration: 399
#
# Currently on Iteration: 400
#
# Currently on Iteration: 401
#
# Currently on Iteration: 402
#
# Currently on Iteration: 403
#
# Currently on Iteration: 404
#
# Currently on Iteration: 405
#
# Currently on Iteration: 406
#
# Currently on Iteration: 407
#
# Currently on Iteration: 408
#
# Currently on Iteration: 409
#
# Currently on Iteration: 410
#
# Currently on Iteration: 411
#
# Currently on Iteration: 412
#
# Currently on Iteration: 413
#
# Currently on Iteration: 414
#
# Currently on Iteration: 415
#
# Currently on Iteration: 416
#
# Currently on Iteration: 417
#
# Currently on Iteration: 418
#
# Currently on Iteration: 419
#
# Currently on Iteration: 420
#
# Currently on Iteration: 421
#
# Currently on Iteration: 422
#
# Currently on Iteration: 423
#
# Currently on Iteration: 424
#
# Currently on Iteration: 425
#
# Currently on Iteration: 426
#
# Currently on Iteration: 427
#
# Currently on Iteration: 428
#
# Currently on Iteration: 429
#
# Currently on Iteration: 430
#
# Currently on Iteration: 431
#
# Currently on Iteration: 432
#
# Currently on Iteration: 433
#
# Currently on Iteration: 434
#
# Currently on Iteration: 435
#
# Currently on Iteration: 436
#
# Currently on Iteration: 437
#
# Currently on Iteration: 438
#
# Currently on Iteration: 439
#
# Currently on Iteration: 440
#
# Currently on Iteration: 441
#
# Currently on Iteration: 442
#
# Currently on Iteration: 443
#
# Currently on Iteration: 444
#
# Currently on Iteration: 445
#
# Currently on Iteration: 446
#
# Currently on Iteration: 447
#
# Currently on Iteration: 448
#
# Currently on Iteration: 449
#
# Currently on Iteration: 450
#
# Currently on Iteration: 451
#
# Currently on Iteration: 452
#
# Currently on Iteration: 453
#
# Currently on Iteration: 454
#
# Currently on Iteration: 455
#
# Currently on Iteration: 456
#
# Currently on Iteration: 457
#
# Currently on Iteration: 458
#
# Currently on Iteration: 459
#
# Currently on Iteration: 460
#
# Currently on Iteration: 461
#
# Currently on Iteration: 462
#
# Currently on Iteration: 463
#
# Currently on Iteration: 464
#
# Currently on Iteration: 465
#
# Currently on Iteration: 466
#
# Currently on Iteration: 467
#
# Currently on Iteration: 468
#
# Currently on Iteration: 469
#
# Currently on Iteration: 470
#
# Currently on Iteration: 471
#
# Currently on Iteration: 472
#
# Currently on Iteration: 473
#
# Currently on Iteration: 474
#
# Currently on Iteration: 475
#
# Currently on Iteration: 476
#
# Currently on Iteration: 477
#
# Currently on Iteration: 478
#
# Currently on Iteration: 479
#
# Currently on Iteration: 480
#
# Currently on Iteration: 481
#
# Currently on Iteration: 482
#
# Currently on Iteration: 483
#
# Currently on Iteration: 484
#
# Currently on Iteration: 485
#
# Currently on Iteration: 486
#
# Currently on Iteration: 487
#
# Currently on Iteration: 488
#
# Currently on Iteration: 489
#
# Currently on Iteration: 490
#
# Currently on Iteration: 491
#
# Currently on Iteration: 492
#
# Currently on Iteration: 493
#
# Currently on Iteration: 494
#
# Currently on Iteration: 495
#
# Currently on Iteration: 496
#
# Currently on Iteration: 497
#
# Currently on Iteration: 498
#
# Currently on Iteration: 499
#
# Currently on Iteration: 500
#
# Currently on Iteration: 501
#
# Currently on Iteration: 502
#
# Currently on Iteration: 503
#
# Currently on Iteration: 504
#
# Currently on Iteration: 505
#
# Currently on Iteration: 506
#
# Currently on Iteration: 507
#
# Currently on Iteration: 508
#
# Currently on Iteration: 509
#
# Currently on Iteration: 510
#
# Currently on Iteration: 511
#
# Currently on Iteration: 512
#
# Currently on Iteration: 513
#
# Currently on Iteration: 514
#
# Currently on Iteration: 515
#
# Currently on Iteration: 516
#
# Currently on Iteration: 517
#
# Currently on Iteration: 518
#
# Currently on Iteration: 519
#
# Currently on Iteration: 520
#
# Currently on Iteration: 521
#
# Currently on Iteration: 522
#
# Currently on Iteration: 523
#
# Currently on Iteration: 524
#
# Currently on Iteration: 525
#
# Currently on Iteration: 526
#
# Currently on Iteration: 527
#
# Currently on Iteration: 528
#
# Currently on Iteration: 529
#
# Currently on Iteration: 530
#
# Currently on Iteration: 531
#
# Currently on Iteration: 532
#
# Currently on Iteration: 533
#
# Currently on Iteration: 534
#
# Currently on Iteration: 535
#
# Currently on Iteration: 536
#
# Currently on Iteration: 537
#
# Currently on Iteration: 538
#
# Currently on Iteration: 539
#
# Currently on Iteration: 540
#
# Currently on Iteration: 541
#
# Currently on Iteration: 542
#
# Currently on Iteration: 543
#
# Currently on Iteration: 544
#
# Currently on Iteration: 545
#
# Currently on Iteration: 546
#
# Currently on Iteration: 547
# Currently on Iteration: 548
#
# Currently on Iteration: 549
#
# Currently on Iteration: 550
#
# Currently on Iteration: 551
#
# Currently on Iteration: 552
#
# Currently on Iteration: 553
#
# Currently on Iteration: 554
#
# Currently on Iteration: 555
#
# Currently on Iteration: 556
#
# Currently on Iteration: 557
#
# Currently on Iteration: 558
#
# Currently on Iteration: 559
#
# Currently on Iteration: 560
#
# Currently on Iteration: 561
#
# Currently on Iteration: 562
#
# Currently on Iteration: 563
#
# Currently on Iteration: 564
#
# Currently on Iteration: 565
#
# Currently on Iteration: 566
#
# Currently on Iteration: 567
#
# Currently on Iteration: 568
#
# Currently on Iteration: 569
#
# Currently on Iteration: 570
#
# Currently on Iteration: 571
#
# Currently on Iteration: 572
#
# Currently on Iteration: 573
#
# Currently on Iteration: 574
#
# Currently on Iteration: 575
#
# Currently on Iteration: 576
#
# Currently on Iteration: 577
#
# Currently on Iteration: 578
#
# Currently on Iteration: 579
#
# Currently on Iteration: 580
#
# Currently on Iteration: 581
#
# Currently on Iteration: 582
#
# Currently on Iteration: 583
#
# Currently on Iteration: 584
#
# Currently on Iteration: 585
#
# Currently on Iteration: 586
#
# Currently on Iteration: 587
#
# Currently on Iteration: 588
#
# Currently on Iteration: 589
#
# Currently on Iteration: 590
#
# Currently on Iteration: 591
#
# Currently on Iteration: 592
#
# Currently on Iteration: 593
#
# Currently on Iteration: 594
#
# Currently on Iteration: 595
#
# Currently on Iteration: 596
#
# Currently on Iteration: 597
#
# Currently on Iteration: 598
#
# Currently on Iteration: 599
#
# Currently on Iteration: 600
#
# Currently on Iteration: 601
#
# Currently on Iteration: 602
#
# Currently on Iteration: 603
#
# Currently on Iteration: 604
#
# Currently on Iteration: 605
#
# Currently on Iteration: 606
#
# Currently on Iteration: 607
#
# Currently on Iteration: 608
#
# Currently on Iteration: 609
#
# Currently on Iteration: 610
#
# Currently on Iteration: 611
#
# Currently on Iteration: 612
#
# Currently on Iteration: 613
#
# Currently on Iteration: 614
#
# Currently on Iteration: 615
#
# Currently on Iteration: 616
#
# Currently on Iteration: 617
#
# Currently on Iteration: 618
#
# Currently on Iteration: 619
#
# Currently on Iteration: 620
#
# Currently on Iteration: 621
#
# Currently on Iteration: 622
#
# Currently on Iteration: 623
#
# Currently on Iteration: 624
#
# Currently on Iteration: 625
#
# Currently on Iteration: 626
#
# Currently on Iteration: 627
#
# Currently on Iteration: 628
#
# Currently on Iteration: 629
#
# Currently on Iteration: 630
#
# Currently on Iteration: 631
#
# Currently on Iteration: 632
#
# Currently on Iteration: 633
#
# Currently on Iteration: 634
#
# Currently on Iteration: 635
#
# Currently on Iteration: 636
#
# Currently on Iteration: 637
#
# Currently on Iteration: 638
#
# Currently on Iteration: 639
#
# Currently on Iteration: 640
#
# Currently on Iteration: 641
#
# Currently on Iteration: 642
#
# Currently on Iteration: 643
#
# Currently on Iteration: 644
#
# Currently on Iteration: 645
#
# Currently on Iteration: 646
#
# Currently on Iteration: 647
#
# Currently on Iteration: 648
#
# Currently on Iteration: 649
#
# SAVING GRAPH AND SESSION

# %%
### Run model on env
env = gym.make('CartPole-v0')

observations = env.reset()
with tf.Session() as sess:
    # https://www.tensorflow.org/api_guides/python/meta_graph
    new_saver = tf.train.import_meta_graph('./models/rf-650-steps-model.meta')
    new_saver.restore(sess,'./models/rf-650-steps-model')

    for x in range(500):
        env.render()
        action_val, gradients_val = sess.run([action, gradients], feed_dict={X: observations.reshape(1, num_inputs)})
        observations, reward, done, info = env.step(action_val[0][0])
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# INFO:tensorflow:Restoring parameters from ./models/my-650-step-model
# WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
